# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import os

# %%
WORK_DIR = os.getcwd()
data_folder = os.path.join(WORK_DIR, "data")


leagues = ['english_premier_league', 'french_ligue_1', 'italian_serie_a', 'spanish_primera_division', 'german_bundesliga_1']

leagues_dict = {
    'english_premier_league': ,
    'french_ligue_1': ,
    'italian_serie_a': ,
    'spanish_primera_division': ,
    'german_bundesliga_1': ,
}

for folder in os.listdir(data_folder):
    temp_path = os.path.join(data_folder, folder)
    
    for file in os.listdir(temp_path):
        filename = os.fsdecode(file)
        
        if filename.endswith('.csv'):
            print('found csv')
            
            for league in leagues:
                
            
            if os.path.basename(filename)[:-4] == leagues[0]:
                print('Found premier leauge')
                eng_temp_df = pd.read_csv(os.path.join(temp_path, filename))
# Out:
# found csv
# found csv
# found csv
# Found premier leauge
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# Found premier leauge
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# Found premier leauge
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# Found premier leauge
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# Found premier leauge
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# Found premier leauge
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# Found premier leauge
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# found csv
# Found premier leauge
# found csv
# found csv
# ...

# %%
eng_temp_df
# Out:
#                    club_name           player_name  age            position  \
# 0                 Arsenal FC             Ben White   23         Centre-Back
# 1                 Arsenal FC       Martin Ødegaard   22  Attacking Midfield
# 2                 Arsenal FC        Aaron Ramsdale   23          Goalkeeper
# 3                 Arsenal FC     Takehiro Tomiyasu   22          Right-Back
# 4                 Arsenal FC  Albert Sambi Lokonga   21    Central Midfield
# ..                       ...                   ...  ...                 ...
# 525               Watford FC        Yaser Asprilla   18  Attacking Midfield
# 526               Watford FC          Maduka Okoye   22          Goalkeeper
# 527  Wolverhampton Wanderers          Hayao Kawabe   26    Central Midfield
# 528  Wolverhampton Wanderers            Toti Gomes   22         Centre-Back
# 529  Wolverhampton Wanderers            Toti Gomes   23         Centre-Back
#
# ...
