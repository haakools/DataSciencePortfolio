# %% [markdown]
# ### Data Wrangling, formatting and importing

# %%
import os
import pandas as pd

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'data', 'data_cleaning.ipynb', 'transfers-master']

# %%
directory = 'data'

for root, dirs, files in os.walk(directory):
    for filename in files:
        print(os.path.join(root, filename))
# Out:
# data\1992\dutch_eredivisie.csv
# data\1992\english_championship.csv
# data\1992\english_premier_league.csv
# data\1992\french_ligue_1.csv
# data\1992\german_bundesliga_1.csv
# data\1992\italian_serie_a.csv
# data\1992\portugese_liga_nos.csv
# data\1992\russian_premier_liga.csv
# data\1992\spanish_primera_division.csv
# data\1993\dutch_eredivisie.csv
# data\1993\english_championship.csv
# data\1993\english_premier_league.csv
# data\1993\french_ligue_1.csv
# data\1993\german_bundesliga_1.csv
# data\1993\italian_serie_a.csv
# data\1993\portugese_liga_nos.csv
# data\1993\russian_premier_liga.csv
# data\1993\spanish_primera_division.csv
# data\1994\dutch_eredivisie.csv
# data\1994\english_championship.csv
# data\1994\english_premier_league.csv
# data\1994\french_ligue_1.csv
# data\1994\german_bundesliga_1.csv
# data\1994\italian_serie_a.csv
# data\1994\portugese_liga_nos.csv
# data\1994\russian_premier_liga.csv
# data\1994\spanish_primera_division.csv
# data\1995\dutch_eredivisie.csv
# ...

# %%
df = pd.read_csv(r'data\2020\french_ligue_1.csv')

# %%
df["player_name"]
# Out:
# 0                Mauro Icardi
# 1                 Sergio Rico
# 2              Danilo Pereira
# 3                     Rafinha
# 4         Alessandro Florenzi
#                 ...
# 652            Didier Desprez
# 653            Cyrille Bayala
# 654              Charles Boli
# 655             Gaëtan Robail
# 656    Aleksandar Radovanovic
# Name: player_name, Length: 657, dtype: object

# %%
with open(r'data\2020\french_ligue_1.csv') as f:
    print(f)
# Out:
# <_io.TextIOWrapper name='data\\2020\\french_ligue_1.csv' mode='r' encoding='cp1252'>

# %%
import io
with io.open(r'data\2020\french_ligue_1.csv', mode='r', encoding = 'ANSI') as file:
    lines = file.read()
