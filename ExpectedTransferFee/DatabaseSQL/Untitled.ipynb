# %%
import requests

season = 2018
league = "premier-league"
league_id = "GB1"

# %%
page = requests.get("https://www.transfermarkt.com/premier-league/transfers/wettbewerb/GB1/saison_id/2018", 
                    headers={'User-Agent': 'Custom'})

# %%
# Parsing pages
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
#  <head>
#   <script type="text/javascript">
#    !function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();
#   </script>
#   <script>
#    window._sp_ = {
#     config: {"accountId":1254,"propertyId":7427,"gdpr":{"consentLanguage":"en"},"baseEndpoint":"https://cdn.privacy-mgmt.com"}}
#   </script>
#   <script async="" src="https://cdn.privacy-mgmt.com/wrapperMessagingWithoutDetection.js">
#   </script>
#   <meta charset="utf-8"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/favicon-16x16.png" rel="shortcut icon" sizes="16x16"/>
#   <link href="/android-chrome-192x192.png" rel="shortcut icon" sizes="192x192"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=no" name="viewport"/>
#   <meta content="Premier League,England" name="keywords"/>
#   <meta content="This overview shows all transfers of the Premier League in the season 18/19. The clubs are ordered by their final position of the previous season." name="description"/>
#   <meta content="article" property="og:type"/>
#   <meta content="https://tmssl.akamaized.net/images/tm_logo.png" property="og:image"/>
#   <meta content="" property="og:description"/>
#   <meta content="Premier League - Transfers 18/19" property="og:title"/>
#   <meta content="https://www.transfermarkt.com/premier-league/transfers/wettbewerb/GB1/saison_id/2018" property="og:url"/>
#   <link href="https://www.transfermarkt.de/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="de" rel="alternate">
#    <link href="https://www.transfermarkt.de/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="de-LU" rel="alternate">
#     <link href="https://www.transfermarkt.at/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="de-AT" rel="alternate"/>
#     <link href="https://www.transfermarkt.ch/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="de-CH" rel="alternate"/>
#     <link href="https://www.transfermarkt.com.tr/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="tr" rel="alternate"/>
#     <link href="https://www.transfermarkt.it/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="it-CH" rel="alternate"/>
#     <link href="https://www.transfermarkt.it/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="it" rel="alternate"/>
#     <link href="https://www.transfermarkt.pl/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="pl" rel="alternate"/>
#     <link href="https://www.transfermarkt.co.uk/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="en-GB" rel="alternate"/>
#     <link href="https://www.transfermarkt.co.uk/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="en-IE" rel="alternate"/>
#     <link href="https://www.transfermarkt.es/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="es" rel="alternate"/>
#     <link href="https://www.transfermarkt.es/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="es-ES" rel="alternate"/>
#     <link href="https://www.transfermarkt.es/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="es-CL" rel="alternate"/>
#     <link href="https://www.transfermarkt.es/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="es-VE" rel="alternate"/>
#     <link href="https://www.transfermarkt.es/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="es-PE" rel="alternate"/>
#     <link href="https://www.transfermarkt.es/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="es-EC" rel="alternate"/>
#     <link href="https://www.transfermarkt.es/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="es-CU" rel="alternate"/>
#     <link href="https://www.transfermarkt.nl/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="nl" rel="alternate"/>
#     <link href="https://www.transfermarkt.pt/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="pt" rel="alternate"/>
#     <link href="https://www.transfermarkt.world/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="ru" rel="alternate"/>
#     <link href="https://www.transfermarkt.world/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="world" rel="alternate"/>
#     <link href="https://www.transfermarkt.fr/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="fr-CH" rel="alternate"/>
#     <link href="https://www.transfermarkt.fr/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="fr" rel="alternate"/>
#     <link href="https://www.transfermarkt.fr/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="fr-CA" rel="alternate"/>
#     <link href="https://www.transfermarkt.fr/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="fr-CI" rel="alternate"/>
#     <link href="https://www.transfermarkt.fr/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="fr-LU" rel="alternate"/>
#     <link href="https://www.transfermarkt.fr/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="fr-BE" rel="alternate"/>
#     <link href="https://www.transfermarkt.com.br/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="pt-BR" rel="alternate"/>
#     <link href="https://www.transfermarkt.us/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="en-US" rel="alternate"/>
#     <link href="https://www.transfermarkt.us/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="en-CA" rel="alternate"/>
#     <link href="https://www.transfermarkt.co.in/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="en-IN" rel="alternate"/>
#     <link href="https://www.transfermarkt.co.za/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="en-ZA" rel="alternate"/>
#     <link href="https://www.transfermarkt.com/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="x-default" rel="alternate"/>
#     <link href="https://www.transfermarkt.com/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="en" rel="alternate"/>
#     <link href="https://www.transfermarkt.be/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="nl-BE" rel="alternate"/>
#     <link href="https://www.transfermarkt.com.ar/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="es-AR" rel="alternate"/>
#     <link href="https://www.transfermarkt.mx/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="es-MX" rel="alternate"/>
#     <link href="https://www.transfermarkt.co/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="es-CO" rel="alternate"/>
#     <link href="https://www.transfermarkt.my/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="ms" rel="alternate"/>
#     <link href="https://www.transfermarkt.jp/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="ja" rel="alternate"/>
#     <link href="https://www.transfermarkt.co.id/premier-league/transfers/wettbewerb/GB1/saison_id/2018" hreflang="id" rel="alternate"/>
#     <link href="https://tmssl.akamaized.net/css/stylesheets/menue.css?lm=1649146668" rel="stylesheet" type="text/css"/>
#     <link href="https://tmssl.akamaized.net/styles/tm-main.min.css?lm=1649146598" rel="stylesheet" type="text/css"/>
#     <link href="https://tmssl.akamaized.net/css/stylesheets/main.css?lm=1649146668" rel="stylesheet" type="text/css"/>
#     <link href="https://tmssl.akamaized.net/css/stylesheets/main_desktop.css?lm=1649146668" rel="stylesheet" type="text/css"/>
#     <link href="https://tmssl.akamaized.net/css/chosen.css?lm=1649146668" rel="stylesheet" type="text/css"/>
#     <link href="https://tmssl.akamaized.net/css/print.css?_sn=1?lm=1649146668" media="print" rel="stylesheet" type="text/css"/>
#     <link href="https://tmssl.akamaized.net/css/wettbewerb.css?lm=1649146668" rel="stylesheet" type="text/css"/>
#     <link href="https://tmssl.akamaized.net/css/statistiken.css?lm=1649146668" rel="stylesheet" type="text/css"/>
#     <script src="https://tmssl.akamaized.net/js/vendor/jquery.min.js?lm=1649146652" type="text/javascript">
#     </script>
#     <script src="https://tmssl.akamaized.net/js/jquery.bxslider.js?lm=1649146652" type="text/javascript">
#     </script>
#     <script src="https://tmssl.akamaized.net/js/main.js?lm=1649146652" type="text/javascript">
#     </script>
#     <script src="https://tmssl.akamaized.net/js/chosen.ajaxaddition.jquery.js?lm=1649146652" type="text/javascript">
#     </script>
#     <script src="https://tmssl.akamaized.net/js/functions.js?lm=1649146652" type="text/javascript">
#     </script>
#     <script src="https://tmssl.akamaized.net/js/main_desktop.js?lm=1649146652" type="text/javascript">
#     </script>
#     <script src="https://tmssl.akamaized.net/js/chosen.jquery.js?lm=1649146652" type="text/javascript">
#     </script>
#     <title>
#      Premier League - Transfers 18/19 | Transfermarkt
#     </title>
#     <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed"/>
#     <link as="script" href="//data-84a0f3455d.transfermarkt.com/iomm/latest/manager/base/es6/bundle.js" id="IOMmBundle" rel="preload"/>
#     <link as="script" href="//data-84a0f3455d.transfermarkt.com/iomm/latest/bootstrap/loader.js" rel="preload"/>
#     <script src="//data-84a0f3455d.transfermarkt.com/iomm/latest/bootstrap/loader.js" type="text/javascript">
#     </script>
#     <script type="text/javascript">
#      tmData = {
#        loggedIn : "0",
#        tmTraffic: "0",
#    };
#     </script>
#     <script>
#      // Set to the same value as the web property used on the site
# 		var gaProperty = 'UA-3816204-13';
#
# 		// Disable tracking if the opt-out cookie exists.
# 		var disableStr = 'ga-disable-' + gaProperty;
# 		if (document.cookie.indexOf(disableStr + '=true') > -1) {
# 			window[disableStr] = true;
# 		}
#
# 		// Opt-out function
# 		function gaOptout() {
# 			document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 			window[disableStr] = true;
# 		}
#     </script>
#     <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3816204-13">
#     </script>
#     <script>
#      window.dataLayer = window.dataLayer || [];
# 	function gtag() { dataLayer.push(arguments); }
#    gtag('set', 'linker', { 'domains': [/^transfermarkt\.(com|de|nl|it|at|ch|es|fr|com\.tr|pt|tv|pl|co\.uk)$/]});
#    gtag('js', new Date());
#    gtag('set',
#   {
#     'custom_map': {
#                     'dimension1': 'loggedIn',
#                     'dimension2': 'tmTraffic'
#                 }
#   });
#         gtag('config', 'UA-3816204-13', {
#                 'anonymize_ip': true,
#                 'transport_type': 'beacon',
#                 'content_group1': 'statistik',
#                 'content_group2': 'wettbewerb',
#                 'content_group3': 'transfers',
#                 'content_group4': 'GB1',
#                 'loggedIn': tmData.loggedIn,
#                 'tmTraffic': tmData.tmTraffic
#             });
#    function tmEvent(category, action, label) {
#                 gtag('event',
#                     action,
#                     {
#                         'event_category': category,
#                         'event_label': label
#                     }
#                 );
#             }
#
#             function tmTiming(value, name, event_category, event_label) {
#                 gtag('event', 'timing_complete', {
#                     name,
#                     value,
#                     event_category,
#                     event_label
#                 });
#             }
#     </script>
#     <script src="https://tmssl.akamaized.net//ads/ads.js" type="text/javascript">
#     </script>
#     <script type="text/javascript">
#      window.tmGaId = "UA-3816204-13";
#     </script>
#     <!--Tisoomi-->
#     <script type="text/javascript">
#      /* 05143122 */ !function(r,e){function t(r,e){var t=ar(r);if(!t)return t;if(""!=e)for(var n=0;n<e.length;n++){var i=u(e,n);"^"==i&&(t=t.parentNode),"<"==i&&(t=t.previousElementSibling),">"==i&&(t=t.nextElementSibling),"y"==i&&(t=t.firstChild)}return t}function n(r,e){var t=ir(e);return{x:r.clientX-t.left,y:r.clientY-t.top}}function i(r){for(var e=0,t=0;r;)e+=r.offsetLeft+r.clientLeft,t+=r.offsetTop+r.clientTop,r=r.offsetParent;return{x:e,y:t}}function o(r,e){var t=0,n=0,o=i(e);return(r.pageX||r.pageY)&&(t=r.pageX,n=r.pageY),(r.clientX||r.clientY)&&(t=r.clientX+document.body.scrollLeft+document.documentElement.scrollLeft,n=r.clientY+document.body.scrollTop+document.documentElement.scrollTop),t-=o.x,n-=o.y,{x:t,y:n}}function l(r,e){return nr(e)?n(r,e):o(r,e)}function d(r,e){r.addEventListener?R(r,"click",e,!0):r.attachEvent&&r.attachEvent("onclick",function(){return e.call(r,window.event)})}function f(e,t){return r[w("c2V0VGltZW91dA==")](e,t)}function s(r){return parseInt(r.toString().split(".")[0],10)}function u(r,e){return r[e]}function p(){return Or=(Ur*Or+Hr)%Xr}function a(){return p()/(Xr-1)}function z(){return a()}function h(r,e){return r>e?r:e}function c(){for(var r="",e=65;e<91;e++)r+=v(e);for(var e=97;e<123;e++)r+=v(e);return r}function v(r){return u(" !\"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ["+u("\\\\",0)+"]^_`abcdefghijklmnopqrstuvwxyz{|}~",r-32)}function w(r){var e,t,n,i,o,l,d,f=c()+"0123456789+/=",s="",p=0;for(r=r.replace(/[^A-Za-z0-9\+\/\=]/g,"");p<r.length;)i=f.indexOf(u(r,p++)),o=f.indexOf(u(r,p++)),l=f.indexOf(u(r,p++)),d=f.indexOf(u(r,p++)),e=i<<2|o>>4,t=(15&o)<<4|l>>2,n=(3&l)<<6|d,s+=v(e),64!=l&&(s+=v(t)),64!=d&&(s+=v(n));return s}function q(){try{return navigator.userAgent||navigator.vendor||window.opera}catch(r){return"unknown"}}function R(r,e,t,n){n=n||!1;try{r.addEventListener(e,t,n)}catch(n){r.attachEvent&&r.attachEvent("on"+e,t)}}function m(r){if(!r)return"";for(var e=w("ISIjJCUmJygpKissLS4vOjs8PT4/QFtcXV5ge3x9"),t="",n=0;n<r.length;n++){t+=e.indexOf(r[n])>-1?w("XA==")+r[n]:r[n]}return t}function g(r){if(!r)return"";var e="";return r.id&&r.id.length>0&&(e+="#"+m(r.id)),r.className&&r.className.length>0&&(e+="."+m(r.className).split(" ").filter(function(r){return r&&r.length>0}).join(".")),e}function k(r){Kr[r]=!1}function x(r,e){var t=Lr++;Kr[t]=!0;var n=function(e){return function(){r.call(null),Kr[t]&&f(n,e)}}(e);return f(n,e),t}function j(r){var e=!1;return Object.keys(r).forEach(function(t){e=e||r[t]}),!e}function y(r,e){return r&&(r.consents&&r.consents[e]||r.legitimateInterests&&r.legitimateInterests[e])}function b(e){return!!r.lzorq35fFlags.strictNCNA&&(y(e,2)&&y(e,7)&&y(e,9)&&y(e,10))}function W(r,e,t){var n=function(){return!!e()&&(t(),!0)};if(!n()){var i=x(function(){n()&&k(i)},250);n()}}function E(r){Z(r)}function Z(r){if(r.lzorq3e1sdl&&!r.lzorq1a0Injct){r.lzorq1a0Injct=!0,r.lzorq1eePc={},r.lzorqff6Oc=[],r.lzorq0d0Am={},r.lzorqa01Av={},r.lzorq22fAw={},r.lzorq9deRqr={},r.lzorqccbRqq=[],r.lzorqa01Avt={},r.lzorq8e0Ev={};var t=[];if(!r.lzorq35fFlags.welect.eenabled||YGXLJWelect()){if(lzorq35fFlags.pta9bls){var n=lzorq35fFlags.ba3abit,i=lzorq35fFlags.mbe81el||10,o=lzorq35fFlags.ig40aBP,l=function(){var r=D("style");r.type="text/css";var t=!1,n=D("style");n.type="text/css";var i=!1;return function(l,d){if(d)if("b"!==l||t){if("r"===l)if(i){var f=n,s=f.sheet;s.insertRule(d,0)}else i=!0,C(n,d),B(e.body,n)}else{if(t=!0,o)for(var u=0;u<o.length;u++)d=d.replace(new RegExp("([;{])"+o[u]+": [^;]+;","g"),"$1");var f="[^:;{",s="!important;";d=d.replace(new RegExp(f+"}]+: [^;]+\\s"+s,"g"),""),C(r,d),e.head.insertBefore(r,e.head.firstChild)}}}();if(n){if(n.length>i){for(var d=0,f=[0],u=[n[0]],p=1;p<i;p++){for(;f.indexOf(d)>-1;)d=s(z()*n.length);f.push(d),u[p]=n[d]}n=u,lzorq35fFlags.ba3abit=u}for(var a={},h=0;h<n.length;h++){var c="string"==typeof n[h]?ar(n[h]):n[h];if(c&&c instanceof Node){var v={element:c,coeb7so:{},rc650cls:Vr(7),co07dtx:""};if(v.co07dtx+="."+v.rc650cls+"{",!o||o&&-1== ...
# var d=[Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2Q]S7G7VtJz\\mrE{Y]UH8;9[M8YuLfYJ9sGuIjZXmLi[M2"+r.lzorq570Rnd+"UYF[Qo<6WMI}XpiGNSiKhj{t5Wo]OLG9n;i6GSpTZK9kWMV1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2GmtzxY6fWZ3mH3NW<K[FTvSW7:Q[S[{ov;<[W35}]{5]2"+r.lzorq570Rnd+"Y\\GSqojx;Ey|pvWjoFpZoT3gk;VuMIkYGM\\TTZRRFkVfrLR1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2TktekU||Up39JegR5p[V9M|XQru6}fg<Q8WNV7SRZh:L2"+r.lzorq570Rnd+"MVFyK6K5NJ5I<GwJWsofLvYrnw9yVhiOh]GMEiWXH]E7yzz1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2yU3jvne6wNkKqu\\\\6}9xjKYMV3qp5{\\wXsPpPTnzRHiV2"+r.lzorq570Rnd+"ZEP[HXF;x[\\jXGUq3tjf::<HM9s\\rmwvZO{:7i{{r7giZfW1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2PR6jUKm9t;PZ|9x9KW<4UJ:J}\\[\\F}}|uEqkGgwrqvRe2"+r.lzorq570Rnd+"\\JYQy;SyjjME44PxItLvYtGNwxXPOTf<Fs4NEPwsRHPsShp1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh24<<7XZ}TLQifI9n;oq:XEtkLN8kTZm]ySxyNF:sX]Qqz2"+r.lzorq570Rnd+"KGRXJ]MvXkWN<e8\\m\\\\I\\9iYgT9Is|qEs5Ty}PKjR{|O[mK1jli",-3)],f=[Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2l9uKgeYp6}3{GUIEZ[[:{LwyuN9gK{JLXwPy]LhZUnGi2"+r.lzorq570Rnd+"OGFLiI<UkVZMet:oug:VUfv5jU8t<[R<u3kSX6g4533UV[Y1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2glVr5keKog]OshmiNkMWIT9PJXVORLTsoXNf3jtxFLHp2"+r.lzorq570Rnd+"GE\\SHR|UPXEI<twzHx:[G}}8NkqGXnVSFRhMrH9vq|;G6|41jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2jSMKkSoGqU9jEk7eNp5t|}[e[9UOiSNw}vVKtV{|j6lW2"+r.lzorq570Rnd+"WNSkP]{Ugo}P<f[SOVuMS5xFR{7GR]Ov:\\]QYR<HqN6XNm41jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2s[mnJ|JVHj|HGmJEMPXgVnSfMvGK;F]Zi:[R7vZ|N:RZ2"+r.lzorq570Rnd+"QY[L<w<6w8kfu3HXESh57\\gyfZOTf|9n[EJ[MHWV4V4h6Nq1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh26XW{MNYHJN4nMoFUK9:k{sFSW77:]URyz53<lmZ[<<IF2"+r.lzorq570Rnd+"PF[4njN{hxqF}3s9\\JTp5u4zsnr:rLySU}UlfhK9GorMez41jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2TYkNqLNM}kVxRO|Q6OK|O<OILN{UVkY5xw6onQpM6P<y2"+r.lzorq570Rnd+"OXTKn:WeofUwU]J77Y7U6pR9T;n[oEN7yZJk;NzK6Lg4oUy1jli",-3)],u=d[1*s(6*t.y/this.offsetHeight)+s(1*t.x/this.offsetWidth)],p=f[1*s(6*t.y/this.offsetHeight)+s(1*t.x/this.offsetWidth)];Rr(r,u,p,"_blank")}}),B(p,f),dr(u,p),r.lzorqdbb94.a[9440]=p,M([{applyAdText:!0}],p,9440),Mr(p,9440,Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2yjn7\\3{IqkSP4PmyRRWe9Mj]yyIkgL}eSks]QvXqfU}e2"+r.lzorq570Rnd+"EFK9T{eGj<Xng|6GhNE;VUj\\ZnQjXLsSsqpeGvmJlyqVL;F1jli",-3)),U(9440,t,!0)}}},function(){U(9440,t,!1)})}function a(e,t,i,o){i||hr(Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2|w\\6F|sZTqQ[[8snz:3\\KpPx{7Lrs}:I{Ky]xkgX[sNX2"+r.lzorq570Rnd+"TQP7vxVLRr}9G4MfYOnq;vttr]}HvX\\5}86}r}LSWt:WY5:1jli",-3),function(){if(!i){i=!0;var f=this;if(f.height<2)return void U(9931,t,!1);if(o==r.lzorq570Rnd){var u=e,p=D("div");n[""+w(Er(w("V1o8bGRae29bMzRWUGpAQA=="),-3))]=p,pr(p,"gteJFHSlVy");var a=f;r.lzorq0d0Am[9931]&&(H(r.lzorq0d0Am[9931]),r.lzorq0d0Am[9931]=!1),d(a,function(e,t){if(!r.lzorq1eePc[9931]){e.preventDefault(),e.stopPropagation();for(var t=l(e,this),n=0;n<r.lzorqff6Oc.length;n++){var i=r.lzorqff6Oc[n];if(9931==i.p&&t.x>=i.x&&t.x<i.x+i.w&&t.y>=i.y&&t.y<i.y+i.h){if(i.u){var o=i.t.length>0?i.t:"_self";o=0==e.button&&e.ctrlKey?"_blank":o,Rr(r,i.u,i.u,o,!0)}return}}var d=[Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh24Pzw8vMzFxUNJf46u}v[t]P{iGKqp{nfR{u7phLXYYNM2"+r.lzorq570Rnd+"MPNOUwX3uKx}fn9II{hhrp{\\x|l3;SsjF7TsO\\{gr<|83n41jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2n3pehRk9r;s:lhhP\\gifwr[VrGfFKPszNKoV4oskT5S:2"+r.lzorq570Rnd+"FJMNgYRZM4lPo:yHm}S5}7IqE]Rq:9kNe[IYLX]4inqeyu\\1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2IktHt}9tjimW67K8]9v[<YEK]OWu|t8jgZgr7U8]rvjK2"+r.lzorq570Rnd+"QSKeJ{jmiI|Uvo3rstRkqxFsRJWORr;:mZwSRjPOKlQ8Lqg1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2OPxUIYvEMQ{[QHHfn6U<o:l}zglk8wp58{9<qiHOKV:y2"+r.lzorq570Rnd+"VEOv;KnW8kNrtLOXVQuRKg{iN|P{vh<xG}rYy[WSojUyeu81jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2T6Us[}6LyP3rkz7e8pWsgogm;RULJK|K:UGPnIG5mXtV2"+r.lzorq570Rnd+"]YOFs7gKIfwfr]IZt8z<Thj3lZXeSN;gvYfuh}<Y3Kp9T4j1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh24siZe3oXv[oqZZNqEMpn<<|PQtl<\\n;g7 ...
# var d=[Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2HRqEpw\\PH3utfZ9sHq{RWFi8QufVLppU6eS}{LWmw5sg2"+r.lzorq570Rnd+"]VJVM4FYSGifYL3f{[jvo|ZwtkY<nghm]O<FShL6L\\5offe1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2JI4qSkT9Lts7vl8WoSK]ysvRrmPPPSiiO89|eGpsYkLe2"+r.lzorq570Rnd+"S]PW6r[QfptWK;m\\p6JxqT\\u9MM}G]gNv34T}5t[twV|jXi1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2gVErwg:]gZgNU6|;EZ<smTuh|iJ]xEhmHmS}mU8LHizq2"+r.lzorq570Rnd+"NRHVxxOJJ835eR}zSkPs|HfM:K4FWZwk\\qg\\VxGYFx;pQy71jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2k]nKnR7873ns<5GyqOYvhlFovl6wQu5noL<S:;EK\\6wK2"+r.lzorq570Rnd+"IZHTXe6|YTFfPlo6MROqL{TSuEK8Ko|[lr;:v|P<nRsnS}R1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh28F5|ppP[j;J7su]E8}RepwTqe]ooY4[FZotwQOh4Hp{H2"+r.lzorq570Rnd+"RMFlWL}oS|gR{:Qk6MLS9Y5oZoy{V:SOOggs3ku3l{pM;5Y1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2iusPPPLyHYMzNk;6vkkf]glyQ59fIX\\SwFuy7NZKr:8W2"+r.lzorq570Rnd+"WH\\];iJKILs]6ovPwPRn<P;w:5GFoo;Z3]\\J\\S]NJW;|\\wy1jli",-3)],f=[Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2TU]NoVeLUS9lFWmTP7H3tJrL4<]g[v{t8{FZYTtVVTFx2"+r.lzorq570Rnd+"YLZxHJoLPVRJw8ZQ<4JpSfeKkshWosUhK;jF:w;N]F]S8KS1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2Fksnj{w6KQTELiVz8Jl9goFPS:g7S7sT6eG}ozW4Ylf|2"+r.lzorq570Rnd+"EQ]rM]O\\kuGIZgOT;WIL\\HVx{MKZSiJlQxPj5;xkvnw[YmH1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2oP6||ETwTMR35jWpvYr<qiFuIqJmp5iGRku9]WU3[mh{2"+r.lzorq570Rnd+"KLPqwFVuyYfzxv8Opq]y:k4TV8RreRqig7TI585VpEl}{M\\1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2GROQ[:hGU3[:3yWFfQiXm8<YKYEU{:\\XOpnQ|lTvzG5E2"+r.lzorq570Rnd+"TVNTYIzW<:M:Q8St{gVFo5RSWZVxPj|E653Og3zsmzO97WL1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2mVkM\\]T5;<{lW8RV;REg\\7hnXp3oqJKSR9KXQEKl<JTm2"+r.lzorq570Rnd+"WVJsgpeTGHL[yYEvTzYx4tFE5mWRGKgQOhR6QM:Uq7JMXfW1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2i39sxmT6w]U[JGOOO]8lNhZ;P\\KFxoz7lFJo]vPMS<8f2"+r.lzorq570Rnd+"PJILOu<LI5{\\L<UXUGNFjw}nxYykG:TNE:jY8xG3\\VUOf[t1jli",-3)],u=d[1*s(6*t.y/this.offsetHeight)+s(1*t.x/this.offsetWidth)],p=f[1*s(6*t.y/this.offsetHeight)+s(1*t.x/this.offsetWidth)];Rr(r,u,p,"_blank")}}),B(p,f),B(u,p);var z=r.lzorqdbb94.a[8695];z&&z.parentNode.removeChild(z),r.lzorqdbb94.a[8705]=p,Mr(p,8705,Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2vpmRKkmj<X77LjEHJ\\M|lVMg7kqhZj\\yo\\sV4m<5:<k72"+r.lzorq570Rnd+"T\\Xj[RYsf:vtPHm;qG8IG7Tl4jn5y:pH<mXNuWQyrZQ<IiO1jli",-3)),U(8705,t,!0)}}},function(){U(8705,t,!1)})}function V(e,n,i){var o=t(""+w(Er(w("TDZRcGdKTHs="),-3)),"");o?n(o,!e,!1,r.lzorq570Rnd):i(8939,!e,!1)}function T(e,t,i,o){i||hr(Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2I]exSpoPT3vn4uX5yWu]<W3rfXI66ts\\m;e|4vLQ[oM\\2"+r.lzorq570Rnd+"[WU{p;UVjRpY<tug7L6p7Xy:xRokNXjM}YgTJskn|T}8y{S1jli",-3),function(){if(!i){i=!0;var f=this;if(f.height<2)return void U(8939,t,!1);if(o==r.lzorq570Rnd){var u=e,p=D("div");n[""+w(Er(w("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94W31Id1FUQEA="),-3))]=p,pr(p,"HGyHvwbRN");var a=f;r.lzorq0d0Am[8939]&&(H(r.lzorq0d0Am[8939]),r.lzorq0d0Am[8939]=!1),d(a,function(e,t){if(!r.lzorq1eePc[8939]){e.preventDefault(),e.stopPropagation();for(var t=l(e,this),n=0;n<r.lzorqff6Oc.length;n++){var i=r.lzorqff6Oc[n];if(8939==i.p&&t.x>=i.x&&t.x<i.x+i.w&&t.y>=i.y&&t.y<i.y+i.h){if(i.u){var o=i.t.length>0?i.t:"_self";o=0==e.button&&e.ctrlKey?"_blank":o,Rr(r,i.u,i.u,o,!0)}return}}var d=[Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh28KG8MpNY5|PlSm7u4fkf3[5ssl}4Xu5i\\pYP4oOogSGe2"+r.lzorq570Rnd+"V]V|:YveEGsRy9k5Ss}}y<elo\\R]SU9g7tXHwWLTnkxp9ii1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2oMr\\uso7l<Rw;}X6slNyK8rQ;3JPM:94kMfmMmvf:rVJ2"+r.lzorq570Rnd+"IXFNfHrxPmyiN9}Qg8k}fxM6YX]jfoqkJFSjGVvGvh}GSop1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2hzEMQ}6r]fVRKlq:VoJRx3Q9gtkerFNktMKrNxOLJ}vE2"+r.lzorq570Rnd+"YFIigFSzSTzjRzTse6;EPHpFfogpLpE]qhIUQQ[MNf}tL4o1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2qrv8NsgU8}]<}s9eUZNlyifhk]LT6lU9;pfM];5GexIP2"+r.lzorq570Rnd+"GTSw3{Jk9u;u:WK[o]RwOKjHY8o:}4YMN<uo[;]oXghXJ4v1jli",-3),Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2:jpL8Y<8i4RpFQF4ghLHxmXIJOPm|\\nS|hJwfzF}W ...
# e.open("GET",Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2KrI3GWG]tR7k<J:oNGl6x3QkwNL8[gs3<G3S6NTlJw<q2"+r.lzorq570Rnd+"M[IS[W\\<qU}V]r\\\\]TeYYoyZehsuqSYHzjq[WV;6[|un6;s1jli",-3),!0),e.setRequestHeader("Content-Type","text/plain"),e.onreadystatechange=function(){if(4===e.readyState&&200===e.status){var t=w(Er(e.response,-3)),n=JSON.parse(t);JSON.stringify(n);r.lzorqdbb9o2=n.css,r.lzorqdbb9o3=n.generic,r.lzorqdbb9o3a=n.altGeneric,r.lzorqdbb9o1=n.url,r.lzorqdbb9o1a=n.altUrl,J()}},e.send()}else br(this),J()};r.lzorq448Mobile?hr(Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2VVf7nv}6sjIJvsqrl[:nGM:GmrjMI9x}\\jFm;Zt<ipTN2"+r.lzorq570Rnd+"ZT\\SoLrE4RL}3PyzuY<\\jEmntZUIWylOtrZk9J9h<}SLK|W1jli",-3),n,n):hr(Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2N}Gq}L]{4xtLU8Vzt]O\\\\k{gOS}fqV]hhqxSKSzFXUw62"+r.lzorq570Rnd+"GW\\]wkXMsWlgivWlSw{f{qSfNYe|4m<Gj5KpuWlE3xhZPS<1jli",-3),n,n)}}function J(){var e=[],t=[];if(e.push({bec1cs:".display_ad",buc0frl:Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2dghqjdjh2}nk:]Y;ETGEWIpOyqz{uv:ovUhoRgEMIR[nz;<tV:H|u2"+r.lzorq570Rnd+"ZVYq8SQ}Wf:OvU98Tv]eX{8PJ|W6RGoHY4t4{f;W3K}PI3o1jli",-3)}),t.push({bec1cs:".display_ad",buc0frl:Er("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2dghqjdjh2Y<p{KtouE<nwOzT3fnj[6E9vENvp9Ru|okvWXUTSFvom2"+r.lzorq570Rnd+"MJTJTN}KZNUHR{qoEgInL[8lOTLlHZEpr[vjQswGk{ms45Q1jli",-3)}),r.lzorqdbb9o3.length>0){e=[];for(var n=0;n<r.lzorqdbb9o3.length;n++)e.push({bec1cs:lzorqdbb9o3[n].bc,buc0frl:lzorqdbb9o3[n].bu})}if(r.lzorqdbb9o3a.length>0){t=[];for(var n=0;n<r.lzorqdbb9o3.length;n++)t.push({bec1cs:lzorqdbb9o3a[n].bc,buc0frl:lzorqdbb9o3a[n].bu})}!function(e,t){if(0!=e.length){var n=D("DIV");C(n,"&nbsp;"),B(Qr,n);for(var i=0,o=0;o<e.length;o++){var l=[],d=[],f=0,s=function(){f++,f===l.length&&((!r.lzorq35fFlags.gnrcfll&&d.length>0||d.length===f)&&(r.lzorqdbb9tc.gn=!0),i++),i==e.length&&(fr(n),r.lzorqdbb9tc.gnd=!0,Y())},u=mr(Qr,e[o].bec1cs);l.push(gr(n,u.b,u.p,s,d));var p=e[o].buc0frl,a=t[o].buc0frl;l.push(function(){hr(p,kr(d,s,a),kr(d,s,a))});for(var z=0;z<l.length;z++)l[z]()}}}(e,t);for(var i=0;i<r.lzorqdbb91.length;i++)r.lzorqdbb91[i]();0==r.lzorqdbb91.length&&(r.lzorqdbb9tc.abd=!0,Y()),(r.lzorqfp||r.lzorq35fFlags.fp)&&O(!0,!1),r.lzorq35fFlags.fnc&&O(!1,!1),r.lzorq35fFlags.fab&&O(!1,!0)}function Q(){if(r.lzorq570Rnd=r.lzorq570Rnd||A(),r.lzorq3e1sdl&&!r.lzorq3e1sdln&&(L(4),r.lzorq3e1sdln=!0),!r.lzorq3e1sdl){r.lzorq3e1sdl=!0,r.lzorq3e1sdln=!0,r.lzorqdbb9genat="05143122",r.lzorqdbb9sthash="e1407",r.lzorqdbb9Domain=Er("wudqvihupdunw1frp",-3),r.lzorq570Rnd=r.lzorq570Rnd||A(),r.lzorqbb2forceimp=!1,r.lzorq35fFlags.newSafDet=!!r.lzorq35fFlags.newSafDet&&r.lzorq35fFlags.newSafDet,r.lzorq35fFlags.nwlforce=!!r.lzorq35fFlags.nwlforce&&r.lzorq35fFlags.nwlforce,r.lzorq35fFlags.gnrcfll=void 0===r.lzorq35fFlags.gnrcfll||r.lzorq35fFlags.gnrcfll,r.lzorq35fFlags.forceImp=!!r.lzorq35fFlags.forceImp&&r.lzorq35fFlags.forceImp,r.lzorq35fFlags.autoRecov=!!r.lzorq35fFlags.autoRecov&&r.lzorq35fFlags.autoRecov,r.lzorq35fFlags.fp=!!r.lzorq35fFlags.fp&&r.lzorq35fFlags.fp,r.lzorq35fFlags.npm=!!r.lzorq35fFlags.npm&&r.lzorq35fFlags.npm,r.lzorq35fFlags.rsp=void 0===r.lzorq35fFlags.rsp||r.lzorq35fFlags.rsp,r.lzorq35fFlags.nwf40lst=!!r.lzorq35fFlags.nwf40lst&&r.lzorq35fFlags.nwf40lst,r.lzorq35fFlags.bl563Up=!!r.lzorq35fFlags.bl563Up&&r.lzorq35fFlags.bl563Up,r.lzorqsc={},r.lzorqsc.tsm={};var e=!1,t=x(function(){if(e=!0,null!=(Qr=ar("body"))){if(r.lzorq69fBody)return;r.lzorq69fBody=!0,k(t);var n=D("style");n.type="text/css",B(Jr,n),P()}},10),n=x(function(){k(n),e||L(4)},100)}}function A(){return Er(_(),3)}function _(){for(var r="khFr2NU8mlGLtKDsV041oJOWydY5znb6uHcRjqIwPiCfxTM9XQBpZ7gEv3eS",e=h(10,1+s(10*z())),t="";t.length<e&&r.length>0;)t+=u(r,s(z()*r.length));return t}function D(r){return e.createElement(r)}function C(r,e){r.innerHTML=e}function B(r,e){r.appendChild(e)}function $(r,e,t){r[w("c2V0QXR0cmlidXRl")](e,t)}function rr(r,e){return r[w("Z2V0QXR0cmlidXRl")](e)}function er(r,e){r[w("cmVtb3ZlQXR0cmlidXRl")](e)}function tr(r,e,t,n){r[w("c3R5bGU=")][w("c2 ...
# i.Node.prototype.appendChild=function(){var r=t.apply(this,arguments);try{var e=arguments[0],n=e&&e.nodeName&&e.nodeName.toLowerCase();if(S(e,n,e.src||e.href,this)&&P())switch(n){case"iframe":tr(e);break;case"a":v(e);break;case"script":X(e)}}catch(r){}return r}}(e.body&&e.body.appendChild,i.Node.prototype.appendChild),function(r){i.Node.prototype.replaceChild=function(){var e=r.apply(this,arguments);try{var t=arguments[0]instanceof i.Element&&arguments[0].querySelector("IFRAME");t&&S(t,"iframe",t.src,this)&&P()&&(/Firefox/.test(i.navigator.userAgent)?R(t,"load",nr,!0):tr(t))}catch(r){}return e}}(i.Node.prototype.replaceChild),X(e),function(r){e.createElement=function(){var t=r.apply(e,arguments);try{if(!P())return t;var n=arguments[0]&&arguments[0].toLowerCase();switch(n){case"iframe":R(t,"load",C,!0);break;case"video":!function(r){t.appendChild=function(){try{var e=arguments[0].localName;if(!S(t,n,t.src))return r.apply(t,arguments);if("source"!==e)return r.apply(t,arguments);if(arguments[0].src&&!t.src)return t.src=arguments[0].src,null}catch(r){}}}(t.appendChild),R(t,"error",Q,!0),R(t,"canplay",Q,!0);break;case"img":t.orgnl_script=e.currentScript;case"div":case"script":X(t)}}catch(r){}return t}}(e.createElement)}}if(!(r[Er("ylghrVfulswLvDouhdg|H{hfxwhg",-3)]||r.location.search.indexOf("forceVideoOff=true")>-1)){r[Er("ylghrVfulswLvDouhdg|H{hfxwhg",-3)]=!0,Array.isArray||(Array.isArray=function(r){return"[object Array]"===Object.prototype.toString.call(r)});var or,lr,dr,ur,pr,zr,hr,cr,vr,wr,qr,Rr,mr,gr,kr,xr,yr,br,Wr,Zr,Vr="eZDEMRLsTU",Tr=["transfermarkt.com","emsservice","adalliance","yahoo","jwplayer","ligatus","lkqd","kameleoon","facebook","native.adscale.de","justpremium","twitter.com","consensu","meetrics","daznplayer","api.rlcdn.com","publisher-assets.spot.im","doubleclick.net/pagead/ppub_config","mdsngpush"],Gr=["t.vi-serve.com/\\?event","servt.vid-play.com/track","pixel.inforsea.com/server/log","prd.jwpltx.com","/gen_204","pp.lp4.io","meetrics.net/data","k.streamrail.com/x","m6r.eu/video/empty","brid.tv/ping.gif"],Nr=["adnxs.com.+\\/prebid","doubleclick.net.+&output=ldjh"],Mr="",Fr=Er("kwwsv=22ylgdsl41wkuhhsl1gh2lpdjh2PO[Xl[:;FrrNuLKx;wHjJqJq:qTn|JjxO;EK9<qOp3Th2JEJu9<yfkPhzG\\qSp;q|v]E[85|{fmzFjoLJ<6{Y8tS{5791jli",-3),Sr=[".ad-element"],Xr="#content_video_ima-ad-container, .fp-engine",Ur=[".dianomi-video-background",".GUI-module__container__thumbnail"],Hr="video",Or="testIframe",Lr=q(),Kr=new RegExp("googlebot/|Googlebot-Mobile|Googlebot-Image|Google favicon|Mediapartners-Google|bingbot|slurp|java|wget|curl|Commons-HttpClient|Python-urllib|libwww|httpunit|nutch|phpcrawl|msnbot|jyxobot|FAST-WebCrawler|FAST Enterprise Crawler|biglotron|teoma|convera|seekbot|gigablast|exabot|ngbot|ia_archiver|GingerCrawler|webmon |httrack|webcrawler|grub.org|UsineNouvelleCrawler|antibot|netresearchserver|speedy|fluffy|bibnum.bnf|findlink|msrbot|panscient|yacybot|AISearchBot|IOI|ips-agent|tagoobot|MJ12bot|dotbot|woriobot|yanga|buzzbot|mlbot|yandexbot|purebot|Linguee Bot|Voyager|CyberPatrol|voilabot|baiduspider|citeseerxbot|spbot|twengabot|postrank|turnitinbot|scribdbot|page2rss|sitebot|linkdex|Adidxbot|blekkobot|ezooms|dotbot|Mail.RU_Bot|discobot|heritrix|findthatfile|europarchive.org|NerdByNature.Bot|sistrix crawler|ahrefsbot|Aboundex|domaincrawler|wbsearchbot|summify|ccbot|edisterbot|seznambot|ec2linkfinder|gslfbot|aihitbot|intelium_bot|facebookexternalhit|yeti|RetrevoPageAnalyzer|lb-spider|sogou|lssbot|careerbot|wotbox|wocbot|ichiro|DuckDuckBot|lssrocketcrawler|drupact|webcompanycrawler|acoonbot|openindexspider|gnam gnam spider|web-archive-net.com.bot|backlinkcrawler|coccoc|integromedb|content crawler spider|toplistbot|seokicks-robot|it2media-domain-crawler|ip-web-crawler.com|siteexplorer.info|elisabot|proximic|changedetection|blexbot|arabot|WeSEE:Search|niki-bot|CrystalSemanticsBot|rogerbot|360Spider|psbot|InterfaxScanBot|Lipperhey SEO Service|CC Metadata Scaper|g00g1e.net|GrapeshotCrawler|urlappendbot|brainobot|fr-crawler|binlar|Simp ...
#     </script>
#     <div class="werbung werbung-header">
#      <!-- Start GPT Tag -->
#      <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#      </script>
#      <script>
#       window.googletag = window.googletag || {cmd: []};
#                           googletag.cmd.push(function() {
#                             googletag.defineSlot("/58778164/Desktop-Billboard-1", [[960, 90], [970, 250], [950, 90], [728, 90], [970, 90]], "div-gpt-ad-1621524903956-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-MediumRectangle-1", [[300, 250], [336, 280]], "div-gpt-ad-1621526463511-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Skyscraper-1", [[160, 600], [336, 280], [300, 250], [300, 600]], "div-gpt-ad-1621527521939-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-MediumRectangle-2", [[336, 280], [300, 250]], "div-gpt-ad-1621528018930-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Skyscraper-2",  [[300, 250], [336, 280], [160, 600], [300, 600]], "div-gpt-ad-1621528123398-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Billboard-2",  [[950, 90], [970, 250], [728, 90], [970, 90], [960, 90]], "div-gpt-ad-1621528173524-0")
#                             .addService(googletag.pubads());
#                              googletag.pubads().enableLazyLoad({
#                                 fetchMarginPercent: 500,
#                                 renderMarginPercent: 200,
#                                 mobileScaling: 2.0});
#                             googletag.pubads().setCentering(true);
#                             googletag.pubads().enableSingleRequest();
#                             googletag.pubads().setTargeting("cg1", ["wettbewerb"]);
#                             googletag.pubads().setTargeting("URL", "www.transfermarkt.com");
#                             googletag.enableServices();
#                           });
#      </script>
#      <!-- End GPT Tag -->
#     </div>
#    </link>
#   </link>
#  </head>
#  <body class="" data-cmp-layer-id="575843" data-tm-tld="com" itemscope="" itemtype="http://schema.org/WebPage">
#   <div class="navibalken hide-for-small" id="navibalken">
#   </div>
#   <div id="main">
#    <div class="werbung-skyscraper-container">
#     <div class="werbung werbung-skyscraper">
#      <!-- /58778164/Desktop-Skyscraper-1 -->
#      <div id="div-gpt-ad-1621527521939-0" style="min-width: 160px; min-height: 250px;">
#       <script>
#        googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621527521939-0"); });
#       </script>
#      </div>
#     </div>
#    </div>
#    <div class="werbung-skyscraperbtf-container">
#     <div class="werbung werbung-skyscraperbtf">
#      <!-- /58778164/Desktop-Skyscraper-2 -->
#      <div id="div-gpt-ad-1621528123398-0" style="min-width: 160px; min-height: 250px;">
#       <script>
#        googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528123398-0"); });
#       </script>
#      </div>
#     </div>
#    </div>
#    <header class="tm-header">
#     <div class="tm-header__box">
#      <a href="/">
#       <img alt="Transfermarkt" class="icon-logo" height="62" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" title="Transfermarkt" width="156"/>
#      </a>
#      <tm-domainswitcher open-list="false" tld="com">
#      </tm-domainswitcher>
#      <div class="tm-header__social-box">
#       <a class="header__social-link" href="https://www.facebook.com/Transfermarkt.global" onclick="tmEvent('SM-Icons_Header','click','Facebook');
# " target="_blank">
#        <img class="header__icon header__icon--facebook" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/fb_icon_hover.svg" width="20"/>
#       </a>
#       <a class="header__social-link" href="https://twitter.com/TMuk_news" onclick="tmEvent('SM-Icons_Header','click','Twitter');
# " target="_blank">
#        <img class="header__icon header__icon--twitter" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/twitter_icon_hover.svg" width="20"/>
#       </a>
#       <a class="header__social-link" href="http://instagram.com/transfermarkt_official" onclick="tmEvent('SM-Icons_Header','click','Instagram');
# " target="_blank">
#        <img class="header__icon header__icon--instagram" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/instagram_icon_hover.svg" width="20"/>
#       </a>
#       <a class="header__social-link" href="/intern/rssguide" onclick="tmEvent('SM-Icons_Header','click','RSS');
# " target="_blank">
#        <img class="header__icon header__icon--rss" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/rss_icon_hover.svg" width="20"/>
#       </a>
#      </div>
#      <div class="tm-header__input-wrapper" id="schnellsuche-platz">
#       <form action="/schnellsuche/ergebnis/schnellsuche" class="tm-header__form" id="schnellsuche" name="schnellsuche">
#        <input autocorrect="off" class="tm-header__input--search-field" name="query" onclick="" placeholder="Enter search term" spellcheck="false" type="text" value=""/>
#        <input alt="search" class="tm-header__input--search-send" type="submit" value=""/>
#       </form>
#       <a class="tm-header__search-detail" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to the player detail search">
#        <img alt="search" class="tm-header__icon-detail-search" height="26" src="https://tmsi.akamaized.net/icons/search_icon_plus_blue_white.svg" width="26"/>
#       </a>
#      </div>
#     </div>
#     <div class="row hide-on-print navihalter">
#      <div class="page_wrapper">
#       <div class="large-12 columns megamenu_container megamenu_dark_bar megamenu_dark">
#        <a class="sticky-logo hide-for-small" href="/">
#         <span class="tm_svg" title="Transfermarkt">
#         </span>
#        </a>
#        <ul class="megamenu" id="mainmenue" itemscope="itemscope" itemtype="http://www.schema.org/SiteNavigationElement">
#         <li id="mobile_hauptmenu_button">
#          <ul id="hauptmenuepunkte">
#           <li class="megamenu_drop_list" id="naviid_news">
#            <a class="megamenu_drop tm-main-nav-el" onclick="tmEvent('News','click','menu');
# ">
#             News
#            </a>
#            <div class="dropdown_fullwidth">
#             <div class="col_12 menue_main_col">
#              <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
#              </img>
#             </div>
#             <div class="col_3 menue_right_col hide-for-small">
#             </div>
#            </div>
#           </li>
#           <li class="megamenu_drop_list" id="naviid_transfers">
#            <a class="megamenu_drop tm-main-nav-el" onclick="tmEvent('Transfers &amp; Gerüchte','click','menu');
# ">
#             Transfers &amp; rumours
#            </a>
#            <div class="dropdown_fullwidth">
#             <div class="col_12 menue_main_col">
#              <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
#              </img>
#             </div>
#             <div class="col_3 menue_right_col hide-for-small">
#             </div>
#            </div>
#           </li>
#           <li class="megamenu_drop_list" id="naviid_marktwerte">
#            <a class="megamenu_drop tm-main-nav-el" onclick="tmEvent('Marktwerte','click','menu');
# ">
#             Market values
#            </a>
#            <div class="dropdown_fullwidth">
#             <div class="col_12 menue_main_col">
#              <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
#              </img>
#             </div>
#             <div class="col_3 menue_right_col hide-for-small">
#             </div>
#            </div>
#           </li>
#           <li class="aktiv megamenu_drop_list" id="naviid_wettbewerbe">
#            <a class="megamenu_drop tm-main-nav-el" onclick="tmEvent('Wettbewerbe','click','menu');
# ">
#             Competitions
#            </a>
#            <div class="dropdown_fullwidth">
#             <div class="col_12 menue_main_col">
#              <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
#              </img>
#             </div>
#             <div class="col_3 menue_right_col hide-for-small">
#             </div>
#            </div>
#           </li>
#           <li class="megamenu_drop_list" id="naviid_foren">
#            <a class="megamenu_drop tm-main-nav-el" href="/uebersicht/index/forum/com" onclick="tmEvent('Foren','click','menu');
# ">
#             Forums
#            </a>
#           </li>
#           <li class="megamenu_drop_list" id="naviid_meintm">
#            <a class="megamenu_drop tm-main-nav-el" onclick="tmEvent('MeinTM','click','menu');
# ">
#             My TM
#            </a>
#            <div class="dropdown_fullwidth">
#             <div class="col_12 menue_main_col">
#              <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
#              </img>
#             </div>
#             <div class="col_3 menue_right_col hide-for-small">
#             </div>
#            </div>
#           </li>
#           <li class="">
#            <a class="live-navilink" href="/ticker/index/live" onclick="tmEvent('Live','click','menu');
# ">
#             Live
#             <tm-live-match-counter auto-request="true" content='["Live match", "live matches"]'>
#             </tm-live-match-counter>
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#        <form action="/schnellsuche/ergebnis/schnellsuche" class="noclose sticky-suche" id="schnellsuche-sticky" name="schnellsuche">
#         <input class="header-suche" name="query" onclick="" placeholder="Enter search term" type="text"/>
#         <input alt="search" class="header-suche-abschicken" src="https://tmssl.akamaized.net//images/suchicon.png" type="image"/>
#        </form>
#        <a class="header-suche-detailsuche" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to the player detail search">
#         <span class="icon-detailsuche">
#         </span>
#        </a>
#        <a href="#" id="arrow-up-xy">
#         <svg enable-background="new 0 0 100 100" height="100px" id="Layer_1" style="fill: white; width: 20px; height: 20px;" version="1.1" viewbox="0 0 100 100" width="100px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#          <g>
#           <path d="M78.016,49.132L51.961,12.714c-0.471-0.66-1.233-1.049-2.043-1.051c-0.006,0-0.006,0-0.006,0
#                                 c-0.815,0.002-1.575,0.396-2.048,1.059L21.977,49.14c-0.546,0.767-0.616,1.776-0.183,2.612c0.426,0.835,1.292,1.361,2.236,1.361
#                                 h12.183l-0.001,32.709c0,1.39,1.125,2.515,2.516,2.515l22.541-0.001c1.389,0.001,2.515-1.124,2.516-2.517l0-32.705h12.187
#                                 c0.94,0,1.803-0.53,2.237-1.367C78.641,50.911,78.566,49.9,78.016,49.132z">
#           </path>
#          </g>
#         </svg>
#        </a>
#        <div class="tm-login" id="login" onclick="tmEvent('login','click','sign_in_button');
# ">
#         <svg class="tm-login__image" enable-background="new 0 0 100 100" fill="#FFF" height="100px" id="Layer_1" version="1.1" viewbox="0 0 100 100" width="100px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#          <g>
#           <path d="M80.161,60.441l-15.66-7.47l-6.622-3.159c2.892-1.822,5.241-4.634,6.778-8.022c1.22-2.69,1.946-5.734,1.946-8.99
#                 c0-1.827-0.29-3.562-0.694-5.236C63.94,19.453,57.605,13.477,50,13.477c-7.461,0-13.701,5.763-15.792,13.645
#                 c-0.482,1.808-0.815,3.688-0.815,5.68c0,3.459,0.808,6.684,2.181,9.489c1.587,3.254,3.94,5.937,6.804,7.662l-6.342,2.953
#                 l-16.168,7.53c-1.404,0.658-2.327,2.242-2.327,4.011v15.062v2.703c0,2.381,1.659,4.312,3.708,4.312h57.505
#                 c2.048,0,3.708-1.93,3.708-4.312v-2.703V64.446C82.46,62.683,81.552,61.114,80.161,60.441z">
#           </path>
#          </g>
#         </svg>
#         <span class="tm-login__cta">
#          Log in
#         </span>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="quick-select-wrapper">
#      <div class="ssc" id="quickselect-skeleton" style="height: 40px;">
#       <div class="ssc-wrapper flex" style="height: 100%; padding: 0">
#        <div class="ssc-square quickselect-element" style="width: 40px;">
#        </div>
#        <div class="ssc-square quickselect-element quickselect-selector" style="width: 171.06px;">
#        </div>
#        <div class="ssc-square quickselect-element quickselect-selector" style="width: 170.84px;">
#        </div>
#        <div class="ssc-square quickselect-element quickselect-selector" style="width: 138.03px;">
#        </div>
#        <div class="ssc-square quickselect-element quickselect-selector" style="width: 141.5px;">
#        </div>
#       </div>
#      </div>
#      <tm-quick-select-bar default-club="" default-competition="GB1" default-country="189" default-player="" dropdown-visible="" translations='{"home":"Home","country":"country","competition":"competition","club":"club","player":"player","attack":"attack","midfield":"midfield","defense":"defence","goalkeeper":"goalkeeper"}'>
#      </tm-quick-select-bar>
#     </div>
#     <div class="werbung werbung-billboard">
#      <!-- /58778164/Desktop-Billboard-1 -->
#      <div id="div-gpt-ad-1621524903956-0" style="min-width: 728px; min-height: 90px;">
#       <script>
#        googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621524903956-0"); });
#       </script>
#      </div>
#     </div>
#    </header>
#    <div id="modalHolder">
#    </div>
#    <div class="row" id="wettbewerb_head">
#     <div class="large-12 columns">
#      <div class="box">
#       <div class="box-header">
#        <span class="spielername-profil">
#         Premier League
#        </span>
#        <div class="hide-for-small icons-profil">
#         <div class="flagge">
#          <a href="/wettbewerbe/national/wettbewerbe/189">
#           <img alt="England" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/small/189.png?lm=1520611569" title="England">
#           </img>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="box-content">
#        <div class="headerfoto">
#         <img alt="Premier League" class="" src="https://tmssl.akamaized.net/images/logo/normal/gb1.png?lm=1521104656" title="Premier League"/>
#        </div>
#        <div class="box-personeninfos">
#         <div class="list">
#          <table class="profilheader">
#           <tr>
#            <th>
#             League level:
#            </th>
#            <td>
#             First Tier -
# ...
#             <img alt="Barnsley FC" class="tiny_wappen" src="https://tmssl.akamaized.net/images/wappen/tiny/349.png?lm=1574162298" title=" "/>
#            </a>
#           </td>
#           <td class="no-border-links verein-flagge-transfer-cell">
#            <img alt="England" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/tiny/189.png?lm=1520611569" title="England"/>
#            <a href="/fc-barnsley/transfers/verein/349/saison_id/2018" title="Barnsley FC">
#             Barnsley FC
#            </a>
#           </td>
#           <td class="rechts">
#            <a href="/jumplist/transfers/spieler/169801/transfer_id/2237954">
#             loan transfer
#            </a>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <div class="di nowrap">
#             <span class="hide-for-small">
#              <a href="/marcelo-djalo/profil/spieler/142022" title="Marcelo Djaló">
#               Marcelo Djaló
#              </a>
#             </span>
#            </div>
#            <div class="di nowrap">
#             <span class="show-for-small">
#              <a href="/marcelo-djalo/profil/spieler/142022" title="Marcelo Djaló">
#               M. Djaló
#              </a>
#             </span>
#            </div>
#           </td>
#           <td class="zentriert alter-transfer-cell">
#            24
#           </td>
#           <td class="zentriert nat-transfer-cell">
#            <img alt="Guinea-Bissau" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/tiny/60.png?lm=1520611569" title="Guinea-Bissau"/>
#            <br/>
#            <img alt="Spain" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/tiny/157.png?lm=1520611569" title="Spain"/>
#           </td>
#           <td class="pos-transfer-cell">
#            Centre-Back
#           </td>
#           <td class="kurzpos-transfer-cell zentriert">
#            CB
#           </td>
#           <td class="rechts mw-transfer-cell">
#            €500Th.
#           </td>
#           <td class="no-border-rechts zentriert">
#            <a href="/extremadura-ud/transfers/verein/29095/saison_id/2018" title="Extremadura UD (-2022)">
#             <img alt="Extremadura UD (-2022)" class="tiny_wappen" src="https://tmssl.akamaized.net/images/wappen/tiny/29095.png?lm=1540553871" title=" "/>
#            </a>
#           </td>
#           <td class="no-border-links verein-flagge-transfer-cell">
#            <img alt="Spain" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/tiny/157.png?lm=1520611569" title="Spain"/>
#            <a href="/extremadura-ud/transfers/verein/29095/saison_id/2018" title="Extremadura UD (-2022)">
#             Extremadura
#            </a>
#           </td>
#           <td class="rechts">
#            <a href="/jumplist/transfers/spieler/142022/transfer_id/2225735">
#             loan transfer
#            </a>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <div class="di nowrap">
#             <span class="hide-for-small">
#              <a href="/timothy-fosu-mensah/profil/spieler/315131" title="Timothy Fosu-Mensah">
#               Timothy Fosu-Mensah
#              </a>
#             </span>
#            </div>
#            <div class="di nowrap">
#             <span class="show-for-small">
#              <a href="/timothy-fosu-mensah/profil/spieler/315131" title="Timothy Fosu-Mensah">
#               T. Fosu-Mensah
#              </a>
#             </span>
#            </div>
#           </td>
#           <td class="zentriert alter-transfer-cell">
#            21
#           </td>
#           <td class="zentriert nat-transfer-cell">
#            <img alt="Netherlands" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/tiny/122.png?lm=1520611569" title="Netherlands"/>
#            <br/>
#            <img alt="Ghana" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/tiny/54.png?lm=1520611569" title="Ghana"/>
#           </td>
#           <td class="pos-transfer-cell">
#            Right-Back
#           </td>
#           <td class="kurzpos-transfer-cell zentriert">
#            RB
#           </td>
#           <td class="rechts mw-transfer-cell">
#            €4.00m
#           </td>
#           <td class="no-border-rechts zentriert">
#            <a href="/manchester-united/transfers/verein/985/saison_id/2018" title="Manchester United">
#             <img alt="Manchester United" class="tiny_wappen" src="https://tmssl.akamaized.net/images/wappen/tiny/985.png?lm=1457975903" title=" "/>
#            </a>
#           </td>
#           <td class="no-border-links verein-flagge-transfer-cell">
#            <img alt="England" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/tiny/189.png?lm=1520611569" title="England"/>
#            <a href="/manchester-united/transfers/verein/985/saison_id/2018" title="Manchester United">
#             Man Utd
#            </a>
#           </td>
#           <td class="rechts bg_gelb_20">
#            <a href="/jumplist/transfers/spieler/315131/transfer_id/2217964">
#             End of loan
#             <br/>
#             <i class="normaler-text">
#              May 31, 2019
#             </i>
#            </a>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <div class="di nowrap">
#             <span class="hide-for-small">
#              <a href="/calum-chambers/profil/spieler/215118" title="Calum Chambers">
#               Calum Chambers
#              </a>
#             </span>
#            </div>
#            <div class="di nowrap">
#             <span class="show-for-small">
#              <a href="/calum-chambers/profil/spieler/215118" title="Calum Chambers">
#               C. Chambers
#              </a>
#             </span>
#            </div>
#           </td>
#           <td class="zentriert alter-transfer-cell">
#            24
#           </td>
#           <td class="zentriert nat-transfer-cell">
#            <img alt="England" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/tiny/189.png?lm=1520611569" title="England"/>
#           </td>
#           <td class="pos-transfer-cell">
#            Centre-Back
#           </td>
#           <td class="kurzpos-transfer-cell zentriert">
#            CB
#           </td>
#           <td class="rechts mw-transfer-cell">
#            €12.00m
#           </td>
#           <td class="no-border-rechts zentriert">
#            <a href="/fc-arsenal/transfers/verein/11/saison_id/2018" title="Arsenal FC">
#             <img alt="Arsenal FC" class="tiny_wappen" src="https://tmssl.akamaized.net/images/wappen/tiny/11.png?lm=1489787850" title=" "/>
#            </a>
#           </td>
#           <td class="no-border-links verein-flagge-transfer-cell">
#            <img alt="England" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/tiny/189.png?lm=1520611569" title="England"/>
#            <a href="/fc-arsenal/transfers/verein/11/saison_id/2018" title="Arsenal FC">
#             Arsenal
#            </a>
#           </td>
#           <td class="rechts bg_gelb_20">
#            <a href="/jumplist/transfers/spieler/215118/transfer_id/2214798">
#             End of loan
#             <br/>
#             <i class="normaler-text">
#              May 31, 2019
#             </i>
#            </a>
#           </td>
#          </tr>
#         </tbody>
#        </table>
#        <div class="transfer-zusatzinfo-box">
#         <span class="transfer-zusatzinfo-alter">
#          Average age of departures: 24.6
#         </span>
#         <span class="transfer-zusatzinfo-wert">
#          Total market value of departures: €32.20m
#         </span>
#         <span class="transfer-einnahmen-ausgaben greentext">
#          Income: €5.35m
#         </span>
#         <br class="clearer"/>
#        </div>
#       </div>
#       <div class="table-footer footer-border">
#        Transfer record:
#        <span class="redtext">
#         €-111.15m
#        </span>
#       </div>
#      </div>
#     </div>
#     <div class="large-4 columns">
#      <div class="werbung werbung-rectangle1">
#       <!-- /58778164/Desktop-MediumRectangle-1 -->
#       <div id="div-gpt-ad-1621526463511-0" style="min-width: 300px; min-height: 250px;">
#        <script>
#         googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621526463511-0"); });
#        </script>
#       </div>
#      </div>
#      <div class="box">
#       <h2 class="content-box-headline">
#        Transfer record
#       </h2>
#       <div class="transferbilanz">
#        <div class="headline">
#         Departures:
#         <b>
#          385
#         </b>
#        </div>
#        <div class="icon">
#         <img src="/images/icons/default_wappen_abgaenge_gruen.png"/>
#        </div>
#        <div class="text">
#         Income:
#         <span class="greentext">
#          €577,524,781
#         </span>
#         <br/>
#         Income per club:
#         <span class="greentext">
#          €28,876,239
#         </span>
#         <br/>
#         Income per player:
#         <span class="greentext">
#          €1,500,064
#         </span>
#        </div>
#        <div class="headline">
#         Arrivals:
#         <b>
#          359
#         </b>
#        </div>
#        <div class="icon">
#         <img src="/images/icons/default_wappen_zugaenge_rot.png"/>
#        </div>
#        <div class="text">
#         Transfer expenses:
#         <span class="redtext">
#          €1,652,060,000
#         </span>
#         <br/>
#         Expenditures per club:
#         <span class="redtext">
#          €82,603,000
#         </span>
#         <br/>
#         Expenditures per player:
#         <span class="redtext">
#          €4,601,838
#         </span>
#        </div>
#        <div class="headline">
#         <b>
#          Total balance
#         </b>
#        </div>
#        <div class="icon">
#         <img src="/images/icons/default_wappen_gesamt_blau.png"/>
#        </div>
#        <div class="text">
#         Total balance:
#         <span class="redtext">
#          €-1,074,535,219
#         </span>
#         <br/>
#         Balance per club:
#         <span class="redtext">
#          €-53,726,761
#         </span>
#         <br/>
#         Balance per player:
#         <span class="redtext">
#          €-3,101,774
#         </span>
#        </div>
#       </div>
#       <br class="clearer"/>
#       <div class="table-footer footer-border">
#        <a href="/transfers/transfersalden/statistik/plus/?sa=&amp;saison_id=">
#         View the international transfer balance
#        </a>
#       </div>
#      </div>
#      <div class="werbung werbung-rectangle2">
#       <!-- /58778164/Desktop-MediumRectangle-2 -->
#       <div id="div-gpt-ad-1621528018930-0" style="min-width: 300px; min-height: 250px;">
#        <script>
#         googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528018930-0"); });
#        </script>
#       </div>
#      </div>
#     </div>
#    </div>
#    <script>
#     if (window.matchMedia('only screen and (max-width: 768px)').matches) {
# 		$('.wappenleiste a').on('click', function () {
# 			event.preventDefault();
# 			var id=$(this).attr('href');
# 			$('html, body').animate({scrollTop: $(id).offset().top-50});
# 		});
# 	} else {
# 		$('.wappenleiste a').on('click', function () {
# 			event.preventDefault();
# 			var id=$(this).attr('href');
# 			$('html, body').animate({scrollTop: $(id).offset().top-110});
# 		});
# 	};
#    </script>
#    <tm-language-hint>
#    </tm-language-hint>
#    <div class="tm-footer">
#     <a class="tm-footer__logo" href="/">
#      <img alt="Transfermarkt" height="33" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" width="80"/>
#     </a>
#     <ul class="tm-footer__links">
#      <li class="tm-footer__links-item">
#       <a href="/intern/impressum">
#        legal notice
#       </a>
#      </li>
#      <li class="tm-footer__links-item">
#       <a href="/intern/web/datenschutz">
#        privacy
#       </a>
#      </li>
#      <li class="tm-footer__links-item">
#       <a class="cmp-link" href="javascript:void(0)">
#        Privacy
#       </a>
#      </li>
#      <li class="tm-footer__links-item">
#       <a href="/intern/anb">
#        general terms of use
#       </a>
#      </li>
#      <li class="tm-footer__links-item">
#       <a href="/intern/tmteam">
#        The TM Team
#       </a>
#      </li>
#      <li class="tm-footer__links-item">
#       <a href="/intern/faq">
#        FAQ
#       </a>
#      </li>
#      <li class="tm-footer__links-item">
#       <a href="/intern/fehlermelden">
#        Found a mistake?
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div id="menue_overlay" style="display: none;">
#    </div>
#   </div>
#   <!-- SZM VERSION="2.0" -->
#   <script type="text/javascript">
#    var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r",
# "co":""
# }
#   </script>
#   <!--/SZM -->
#   <script type="module">
#    var defaultOptions={tracking:!0,refreshAds:!0};export var refreshAd=function(){var e,n;[ASCDP.hasOwnProperty("adS"),null===(e=ASCDP.adS)||void 0===e?void 0:e.hasOwnProperty("reloadAds"),"function"==typeof(null===(n=ASCDP.adS)||void 0===n?void 0:n.reloadAds)].every(function(e){return e})&&ASCDP.adS.reloadAds()};export var TmTrackingAndAds=function(e,n){void 0===n&&(n=defaultOptions);var r=["tabelle","reiter","forum"].includes(e)?e:"";n.tracking&&(gtag("event","page_view",{page_path:"/jsContent"+window.location.pathname}),sendIvwData(r)),n.refreshAds&&"undefined"!=typeof ASCDP&&refreshAd()};window.tmTrackingAndAds=function(e,n){return TmTrackingAndAds(e,n)};
#   </script>
#   <script type="text/javascript">
#    if(typeof IOMm === 'function') {
#             IOMm('configure', { st: iam_data.st, dn: 'data-84a0f3455d.transfermarkt.com', mh:5 });
#             IOMm('pageview', { cp: iam_data.cp, co: iam_data.co });
#         } else {
#             console.warn('IOMm is not defined');
#         }
#   </script>
#   <script type="text/javascript">
#    if(typeof(adet) == "boolean" && adet == false){
# 		img_src="/static/singlepictures/jk99hhfsdh209nbnkjldgh90sghfsdlk";
# 	} else {
# 		img_src="/static/singlepictures/jku90whjlkjbwbta1g4b8h89fh8sgh8d";
# 	}
# 	var elem = document.createElement("img");
# 	document.body.appendChild(elem);
# 	elem.src = img_src;
#   </script>
#   <script defer="" src="https://tmsi.akamaized.net/js/globals/tm-global-elements.esm.js" type="module">
#   </script>
#   <script defer="" nomodule="" src="https://tmsi.akamaized.net/js/globals/tm-global-elements.js">
#   </script>
#   <tm-language-hint>
#   </tm-language-hint>
#   <script src="https://tmssl.akamaized.net/js/libs/micromodal.min.js?lm=1649146652" type="text/javascript">
#   </script>
#   <script src="https://tmssl.akamaized.net/js/libs/intersection-observer.min.js?lm=1649146652" type="text/javascript">
#   </script>
#   <script src="https://tmssl.akamaized.net/js/libs/lazyload.min.js?lm=1649146652" type="text/javascript">
#   </script>
#   <script src="https://tmssl.akamaized.net/js/custom/tm-menu.min.js?lm=1649146652" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /*<![CDATA[*/
# function skyscraperSwitch() {
#                 const firstAd = document.getElementsByClassName("werbung-skyscraper");
#                 const secondAd = document.getElementsByClassName("werbung-skyscraperbtf")
#                 if (this.scrollY > 699) {
#                     firstAd[0].style.visibility = "hidden";
#                     secondAd[0].style.position = "fixed";
#                     secondAd[0].style.top = "40px";
#                 } else {
#                     firstAd[0].style.visibility = "visible";
#                     secondAd[0].style.position = "relative";
#                     secondAd[0].style.top = "unset";
#                 }
#             }
#             window.addEventListener("scroll", skyscraperSwitch, false);
# 	var loginUrl='/profil/login';
# 	var onlyDE = '';
# 	var onlyMobile = '';
# 	var onlyTablet = '';
# 	var getUserID = '';
#
# function sendIvwData(typ) {
#     if(typ == 'tabelle') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_t",
# "co":""
# }
#
#     }else if(typ == 'reiter') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_r",
# "co":""
# }
#
#     }else if(typ == 'forum') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_forum",
# "co":""
# }
#
#     }else {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_s",
# "co":""
# }
#
#     }
#     if(typeof IOMm === 'function') {
#         IOMm('pageview', { cp: iam_data.cp, co: iam_data.co });
#     }
# }
# /*]]>*/
#   </script>
#  </body>
# </html>

# %% [markdown]
# # Parsing tables

# %%
table = soup.find(class_="box")

# %%
table
# Out:
# <div class="box">
# <div class="box-header">
# <span class="spielername-profil">Premier League</span>
# <div class="hide-for-small icons-profil">
# <div class="flagge">
# <a href="/wettbewerbe/national/wettbewerbe/189">
# <img alt="England" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/small/189.png?lm=1520611569" title="England"> </img></a>
# </div>
# </div>
# </div>
# <div class="box-content">
# <div class="headerfoto">
# <img alt="Premier League" class="" src="https://tmssl.akamaized.net/images/logo/normal/gb1.png?lm=1521104656" title="Premier League"/> </div>
# <div class="box-personeninfos">
# <div class="list">
# <table class="profilheader">
# <tr>
# <th>League level:</th>
# <td>
#                                     First Tier - <img alt="England" class="miniflagge" src="https://tmssl.akamaized.net/images/flagge/tiny/189.png?lm=1520611569" title="England"/> England                                </td>
# </tr>
# <tr>
# <th>Number of teams:</th>
# <td>
#                                     20 teams                                </td>
# </tr>
# <tr>
# <th>Players:</th>
# <td>
#                                     502                                </td>
# </tr>
# <tr>
# <th>Foreigners:</th>
# <td>
# <a href="/premier-league/gastarbeiter/wettbewerb/GB1">329 Players</a>  <span class="tabellenplatz">65.5%</span> </td>
# </tr>
# <tr>
# <th>ø-Market value:</th>
# <td>
#                                         €17.23m                                    </td>
# </tr>
# </table>
# </div>
# <div class="list">
# <table class="profilheader">
# <tr>
# <th>UEFA coefficient:</th>
# <td>
# <a href="/uefa/5jahreswertung/statistik">1. Pos.</a>  <span class="tabellenplatz">102.926 </span><span class="tabellenplatz">Points</span> </td>
# </tr>
# <tr>
# <th>Record-holding champions:</th>
# <td>
# <a href="/manchester-united/startseite/verein/985" title="Manchester United">Manchester United</a>  <span class="tabellenplatz">20 </span><span class="tabellenplatz">time(s)</span> </td>
# </tr>
# <tr>
# <th>
#                                                                             ø-Age:
#                                                                         </th>
# <td>
#                                     27.4                                </td>
# </tr>
# <tr>
# <th>Reigning champion:</th>
# <td>
# <a href="/manchester-city/startseite/verein/281" title="Manchester City">Manchester City</a> </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# </div>

# %%
table_body = table.find('tbody')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-d4922059800d> in <module>
# ----> 1 table_body = table.find('tbody')
#
# ~\.conda\envs\datascience\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2251     def __getattr__(self, key):
#    2252         """Raise a helpful exception to explain a common code fix."""
# -> 2253         raise AttributeError(
#    2254             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2255         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
