# %%
import time
from selenium import webdriver
from datetime import datetime
import os
from bs4 import BeautifulSoup
import pandas as pd
import random
import func_lib as fn

# %% [markdown]
# ## Fbref.com webscraping

# %% [markdown]
# ### To run this download the chromium webdriver for selenium and put the chromedriver.exe in the working directory (i.e. along with this file)
# ### This webscraper saves the entire table shown in the figure below, found at webpage (https://fbref.com/en/comps/13/stats/Ligue-1-Stats)

# %% [markdown]
# ### ![fbref_table.png](attachment:fbref_table.png)

# %% [markdown]
# ### Although this website allows the viewer to highlight and copy the data as csv, running a webscraper easily helps the strain of carefully selecting and copying.

# %% [markdown]
# ### Running the webdriver

# %%
# Intizializing inputs
chrome_path = os.getcwd() + '\\chromedriver.exe'

url = 'https://fbref.com/en/comps/20/stats/Bundesliga-Stats'

league_name = "Bundesliga"

year_stop = "92"

# Running webscraper
fn.webscraper(url, chrome_path, league_name, year_stop)
