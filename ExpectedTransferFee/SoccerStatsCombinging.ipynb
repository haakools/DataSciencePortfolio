# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
workdir = os.getcwd()
print(workdir)
# Out:
# C:\Users\hakon\Documents\GitHub\DataSciencePortfolio\ExpectedTransferFee

# %%
data_path = os.path.join(workdir, "WebScraping\data")
print(data_path)
# Out:
# C:\Users\hakon\Documents\GitHub\DataSciencePortfolio\ExpectedTransferFee\WebScraping\data

# %%
for folder in os.listdir(data_path):
    temp_folder_path = os.path.join(data_path, folder)
    league_df = pd.DataFrame()
    for file in os.listdir(temp_folder_path):
        temp_df = pd.read_csv(os.path.join(temp_folder_path, file))
    league_df = pd.concat([league_df, temp_df])
    league_column = pd.DataFrame({'league' : [league for i in range(len(transfer_df))]})
# Out:
# Bundesliga_1992-1993.csv
# Bundesliga_1993-1994.csv
# Bundesliga_1994-1995.csv
# Bundesliga_1995-1996.csv
# Bundesliga_1996-1997.csv
# Bundesliga_1997-1998.csv
# Bundesliga_1998-1999.csv
# Bundesliga_1999-2000.csv
# Bundesliga_2000-2001.csv
# Bundesliga_2001-2002.csv
# Bundesliga_2002-2003.csv
# Bundesliga_2003-2004.csv
# Bundesliga_2004-2005.csv
# Bundesliga_2005-2006.csv
# Bundesliga_2006-2007.csv
# Bundesliga_2007-2008.csv
# Bundesliga_2008-2009.csv
# Bundesliga_2009-2010.csv
# Bundesliga_2010-2011.csv
# Bundesliga_2011-2012.csv
# Bundesliga_2012-2013.csv
# Bundesliga_2013-2014.csv
# Bundesliga_2014-2015.csv
# Bundesliga_2015-2016.csv
# Bundesliga_2016-2017.csv
# Bundesliga_2017-2018.csv
# Bundesliga_2018-2019.csv
# Bundesliga_2019-2020.csv
# Bundesliga_2020-2021.csv
# Bundesliga_2021-2022.csv
# English_Premier_League_1992-1993.csv
# English_Premier_League_1993-1994.csv
# English_Premier_League_1994-1995.csv
# English_Premier_League_1995-1996.csv
# ...

# %%
df = pd.read_csv(data_path+"\Bundesliga\Bundesliga_2019-2020.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Nation', 'Pos', 'Squad', 'Age', 'Born', 'MP',
#        'Starts', 'Min', '90s', 'Gls', 'Ast', 'G-PK', 'PK', 'PKatt', 'CrdY',
#        'CrdR', 'Gls.1', 'Ast.1', 'G+A', 'G-PK.1', 'G+A-PK', 'xG', 'npxG', 'xA',
#        'npxG+xA', 'xG.1', 'xA.1', 'xG+xA', 'npxG.1', 'npxG+xA.1', 'Matches',
#        'Season'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 34

# %%
df_2 = pd.read_csv(data_path+"\Bundesliga\Bundesliga_2007-2008.csv")

# %%
len(df_2.columns)
# Out:
# 25

# %%
print(df.columns)
print(df_2.columns)
# Out:
# Index(['Unnamed: 0', 'Player', 'Nation', 'Pos', 'Squad', 'Age', 'Born', 'MP',
#        'Starts', 'Min', '90s', 'Gls', 'Ast', 'G-PK', 'PK', 'PKatt', 'CrdY',
#        'CrdR', 'Gls.1', 'Ast.1', 'G+A', 'G-PK.1', 'G+A-PK', 'xG', 'npxG', 'xA',
#        'npxG+xA', 'xG.1', 'xA.1', 'xG+xA', 'npxG.1', 'npxG+xA.1', 'Matches',
#        'Season'],
#       dtype='object')
# Index(['Unnamed: 0', 'Player', 'Nation', 'Pos', 'Squad', 'Age', 'Born', 'MP',
#        'Starts', 'Min', '90s', 'Gls', 'Ast', 'G-PK', 'PK', 'PKatt', 'CrdY',
#        'CrdR', 'Gls.1', 'Ast.1', 'G+A', 'G-PK.1', 'G+A-PK', 'Matches',
#        'Season'],
#       dtype='object')

# %%
pd.concat([df, df_2])
# Out:
#      Unnamed: 0              Player  Nation    Pos            Squad  Age  \
# 0             0  Suleiman Abdullahi  ng NGA  FW,MF     Union Berlin   22
# 1             1       David Abraham  ar ARG     DF   Eint Frankfurt   33
# 2             2        Amir Abrashi  al ALB     MF         Freiburg   29
# 3             3         Tyler Adams  us USA  MF,DF       RB Leipzig   20
# 4             4      Sargis Adamyan  am ARM  FW,MF       Hoffenheim   26
# ..          ...                 ...     ...    ...              ...  ...
# 478         497       Daniel Ziebig  de GER  DF,MF  Energie Cottbus   24
# 479         498        Marc Ziegler  de GER     GK         Dortmund   31
# 480         499           Sal Zizzo  us USA  DF,MF      Hannover 96   20
# 481         500       Sibusiso Zuma  za RSA  FW,MF          Arminia   32
# 482         501       Dariusz Żuraw  pl POL     DF      Hannover 96   34
#
#      Born  MP  Starts    Min  ...  npxG   xA  npxG+xA  xG.1  xA.1  xG+xA  \
# ...
